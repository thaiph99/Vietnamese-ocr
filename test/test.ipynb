# %%
import matplotlib.pyplot as plt
from PIL import Image

from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg
from time import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_658/881312479.py in <module>
#       2 from PIL import Image
#       3
# ----> 4 from vietocr.tool.predictor import Predictor
#       5 from vietocr.tool.config import Cfg
#       6 from time import time
#
# ~/.local/lib/python3.8/site-packages/vietocr/tool/predictor.py in <module>
# ----> 1 from vietocr.tool.translate import build_model, translate, translate_beam_search, process_input, predict
#       2 from vietocr.tool.utils import download_weights
#       3
#       4 import torch
#       5
#
# ~/.local/lib/python3.8/site-packages/vietocr/tool/translate.py in <module>
# ----> 1 import torch
#       2 import numpy as np
#       3 import math
#       4 from PIL import Image
#       5 from torch.nn.functional import log_softmax, softmax
#
# ModuleNotFoundError: No module named 'torch'

# %%
config = Cfg.load_config_from_name('vgg_transformer')

config['weights'] = 'https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA'
config['cnn']['pretrained'] = False
config['device'] = 'cuda:0'
config['predictor']['beamsearch'] = False

detector = Predictor(config)
# Out:
# File exists: /home/it/.cache/gdown/https-COLON--SLASH--SLASH-drive.google.com-SLASH-uc-QUESTION-id-EQUAL-13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA

# %%
from os import listdir
imgs = listdir('../datatest/test2')

# %%
for img in imgs:
    start = time()
    img = '../datatest/test2/'+img
    img = Image.open(img)
    plt.imshow(img)

    ans = detector.predict(img, return_prob=True)
    print(ans)
    plt.show()
    print('time : ', time()-start)
    print('----------------------')
# Out:
# ('Năm mươi ba triệu bảy trầm mười hai nghìn nlĩm trilim sáu mươi đồng', 0.9146545591639049)
# time :  0.4418156147003174
# ----------------------
# ('BELLER', 0.19567837938666344)
# time :  0.1728203296661377
# ----------------------
# ('Tên khách nàng', 0.882398750100817)
# time :  0.1564037799835205
# ----------------------
# ('Địa chỉ: Lô C6-2 KCN Quế Vô - Bắc Ninh', 0.913317405863812)
# time :  0.28273987770080566
# ----------------------
# ('Tổng cộng tiền thanh toàn', 0.9075739169120789)
# time :  0.22598934173583984
# ----------------------
# ('03800000055', 0.2524443106217818)
# time :  0.15919756889343262
# ----------------------
# ('Công ty Điện lực bắc ninh', 0.8987251281738281)
# time :  0.21432995796203613
# ----------------------
# ('NỘI THẤT ÔTÔ VÀ ĐỒ CHƠI XE HƠI', 0.9133916278680165)
# time :  0.24098730087280273
# ----------------------
# ('03800000099', 0.26815070618282666)
# time :  0.1542673110961914
# ----------------------
# ('chữ viết tay trên 1 dòng', 0.9350680559873581)
# time :  0.22307872772216797
# ----------------------
# ('03600000000', 0.2283627756617286)
# time :  0.15965008735656738
# ----------------------
# ('20/09/2012', 0.9333476901054383)
# time :  0.132035493850708
# ----------------------
# ('Ell', 0.8200177351633707)
# time :  0.19246983528137207
# ----------------------
# ('Mã só thuế (Tax code): 0 302643.825', 0.8976825092520032)
# time :  0.2622087001800537
# ----------------------
# ('Lêm', 0.338454137245814)
# time :  0.13148999214172363
# ----------------------
# ('Pi', 0.5091574266552925)
# time :  0.10399007797241211
# ----------------------
# ('53.712560', 0.9289705355962118)
# time :  0.13460254669189453
# ----------------------
# ('CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ TRỰC TUYẾN TRƯỜNG MINH THỊNH', 0.9278682025652083)
# time :  0.4042229652404785
# ----------------------
# ('Thành tiền', 0.9156831920146942)
# time :  0.14026618003845215
# ----------------------
