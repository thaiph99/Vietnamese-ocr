# %%
import easyocr
reader = easyocr.Reader(['en'])
path_image = '../datatest/the-bill-very-reasonable.jpg'
result = reader.readtext(path_image)

result
# Out:
# /home/it/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# [([[180, 26], [416, 26], [416, 67], [180, 67]],
#   'MAGNOLIA RESTAURANT',
#   0.9960909181617762),
#  ([[224, 51], [311, 51], [311, 71], [224, 71]],
#   'Address; S85T,',
#   0.20833342770733285),
#  ([[319, 63], [377, 63], [377, 77], [319, 77]],
#   'AStcu (51 )',
#   0.1952573118706111),
#  ([[284, 71], [345, 71], [345, 90], [284, 90]],
#   '012524477',
#   0.24897508010059857),
#  ([[148, 99], [201, 99], [201, 117], [148, 117]],
#   'NV Nc)',
#   0.5251430620650691),
#  ([[226, 90], [313, 90], [313, 117], [226, 117]],
#   'Settlement',
#   0.998914993830543),
#  ([[144, 116], [203, 116], [203, 133], [144, 133]],
#   'PA NO',
#   0.6406745832434811),
#  ([[299, 115], [351, 115], [351, 131], [299, 131]],
#   'TTable No',
#   0.7075125464835966),
#  ([[145, 137], [213, 137], [213, 153], [145, 153]],
#   'OPEN TINE',
#   0.43081282923605574),
#  ([[298, 130], [337, 130], [337, 147], [298, 147]],
#   'DATE',
#   0.9995635151863098),
#  ([[245, 145], [275, 145], [275, 157], [245, 157]],
#   '13.18',
#   0.2768867992283619),
#  ([[301, 149], [365, 149], [365, 165], [301, 165]],
#   'TIME OUT',
#   0.8676348618295806),
#  ([[398, 160], [420, 160], [420, 168], [398, 168]],
#   '[4,40',
#   0.177499001579085),
#  ([[160, 160], [225, 160], [225, 178], [160, 178]],
#   'Dezeriptiou',
#   0.49956740116541615),
#  ([[410, 178], [451, 178], [451, 191], [410, 191]],
#   'Amie II',
#   0.017520991753715003),
#  ([[189, 183], [227, 183], [227, 197], [189, 197]],
#   'Wine',
#   0.8344315886497498),
#  ([[157, 201], [257, 201], [257, 221], [157, 221]],
#   '22-Pho W beet"',
#   0.6244957590584891),
#  ([[381, 215], [407, 215], [407, 229], [381, 229]],
#   '3,50',
#   0.9759764075279236),
#  ([[157, 225], [251, 225], [251, 241], [157, 241]],
#   '71-Paneake W',
#   0.4487084422997555),
#  ([[153, 245], [231, 245], [231, 259], [153, 259]],
#   'MUSHrocin',
#   0.18540872819183413),
#  ([[443, 247], [467, 247], [467, 261], [443, 261]], 'L,Wu', 0.10972910374403),
#  ([[273, 277], [345, 277], [345, 293], [273, 293]],
#   'SUR TOTAL',
#   0.8988695109608236),
#  ([[437, 283], [475, 283], [475, 301], [437, 301]],
#   '14,5u',
#   0.2830120557986897),
#  ([[270, 314], [345, 314], [345, 333], [270, 333]],
#   'DIS( OUNT :',
#   0.48826282916697894),
#  ([[269, 341], [327, 341], [327, 355], [269, 355]],
#   'SERVICT',
#   0.5778582974039956),
#  ([[269, 365], [315, 365], [315, 381], [269, 381]],
#   'TOTAL',
#   0.973204144660679),
#  ([[441, 365], [485, 365], [485, 385], [441, 385]],
#   '1+,50',
#   0.314329165894144),
#  ([[269, 401], [339, 401], [339, 413], [269, 413]],
#   'Belore VAT',
#   0.6682165300150418),
#  ([[261.3273272060037, 70.26005992660406],
#    [283.97513285579146, 73.77837889641103],
#    [281.6726727939963, 82.73994007339594],
#    [260.02486714420854, 79.22162110358897]],
#   '44:',
#   0.10799153503897363),
#  ([[311.1055728090001, 98.21114561800017],
#    [368.97552593065814, 105.68807485305398],
#    [365.8944271909999, 121.78885438199983],
#    [308.02447406934186, 115.31192514694602]],
#   'Rtecord',
#   0.3426176757798936),
#  ([[239.47000105999683, 107.15200169599491],
#    [279.9814905920257, 111.80848964058035],
#    [277.52999894000317, 124.84799830400509],
#    [237.0185094079743, 120.19151035941965]],
#   '102572',
#   0.6202882716472711),
#  ([[377.1055728090001, 134.21114561800016],
#    [434.97552593065814, 141.688074853054],
#    [431.8944271909999, 157.78885438199984],
#    [374.02447406934186, 151.311925146946]],
#   '16 03.2017',
#   0.582502003132314),
#  ([[373.3902892391503, 174.2073760108954],
#    [399.98328200498446, 178.8179107398177],
#    [397.6097107608497, 188.7926239891046],
#    [371.01671799501554, 184.1820892601823]],
#   'Zics',
#   0.08262047916650772),
#  ([[158.98595974687322, 177.27613156968445],
#    [188.86999505263557, 181.2906915317589],
#    [186.01404025312678, 197.72386843031555],
#    [156.13000494736443, 193.7093084682411]],
#   '822-',
#   0.9734035134315491)]

# %%
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = Image.open(path_image)
img = np.array(img)

plt.imshow(img)

print(img.shape)

for item in result:
    # print(item[0][0])
    # print(item[0][2])
    cv2.rectangle(img, tuple(item[0][0]), tuple(item[0][2]), (0, 3, 4), 2)
plt.imshow(img)
# Out:
# (413, 550, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a873dc135c44> in <module>
#      13     # print(item[0][0])
#      14     # print(item[0][2])
# ---> 15     cv2.rectangle(img, tuple(item[0][0]), tuple(item[0][2]), (0, 3, 4), 2)
#      16 plt.imshow(img)
#
# TypeError: function takes exactly 4 arguments (2 given)
